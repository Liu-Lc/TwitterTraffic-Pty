# %% [markdown]
# Generar un mapa de áreas para indicar los lugares con cierta cantidad de tweets y ponerlos en rango de color (reporte)
#
# Generar el random point en las carreteras, o mejorer el proceso hacia el diagrama planteado.
#
# Delimitar el área de las carreteras solo a la ciudad de Panamá

# %%
import psycopg2 as ps
from wordcloud import WordCloud
import  matplotlib.pyplot as plt 
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px

import re, sys
import numpy as np

# sys.path.append('./TweetData')
# from TweetData 
import keys, Preprocessing, Detection

import pandas as pd
import json
from collections import Counter
from fuzzywuzzy import fuzz, process

import geopandas as gpd

# %%
from Detection import rf_classifier, vectorizer3

# %% [markdown]
# ## Misc

# %%
places1 = places.copy()
places1.geom = places1.geom.to_crs(epsg=4326)

# %%
def generate_scatter(df, geom, info):
    fig = go.Figure(
        go.Scattermapbox(
            lat=df[geom].y, lon=df[geom].x,
            marker=go.scattermapbox.Marker(
                size=10,
                color='red',
                opacity=0.7
            ),
            text=df[info],
            hoverinfo=['text']
        )
    )
    fig.update_geos(
        resolution=110,
    )
    fig.update_layout(margin={"r":0,"t":50,"l":0,"b":0},
        mapbox_style="open-street-map", mapbox_zoom=11,
        mapbox_center={'lat':8.99, 'lon':-79.5359},
        title='Mapa de lugares',
        hoverlabel=dict(
            bgcolor="white",
            font_size=12,
        )
    )
    return fig

# %% [markdown]
# ## Places queries

# %%
## Get all tweets no places
conn = ps.connect(
    database='traffictwt', user='postgres', password='root')
cursor = conn.cursor()
q = '''SELECT TWEET_ID, TWEET_TEXT FROM TWEETS ORDER BY TWEET_CREATED DESC LIMIT 50'''
cursor.execute(q)
tweets = cursor.fetchall()
cursor.close()
conn.close()

tweets = pd.DataFrame(tweets, columns=['id', 'text'])

# %%
# Get list of places
conn = ps.connect(
    database='traffictwt', user='postgres', password='root')
q = '''SELECT OSM_ID, NAME, ST_CENTROID(way) as geom FROM PLACES '''
places = gpd.GeoDataFrame.from_postgis(q, conn, geom_col='geom')

# %%
# Get list of roads
conn = ps.connect(
    database='traffictwt', user='postgres', password='root')
q1 = '''SELECT GID, NOMBRE, GEOM FROM carreteras WHERE NOMBRE IS NOT NULL '''
roads = gpd.GeoDataFrame.from_postgis(q1, conn, geom_col='geom')

# %% [markdown]
# ### Get tweets with places assigned

# %%
# Get tweets roads
conn = ps.connect(
    database='traffictwt', user='postgres', password='root')
q1 = '''SELECT TP.TWEET_ID, T.TWEET_TEXT, R.NOMBRE AS ROAD_NAME, ST_CENTROID(R.GEOM) AS ROAD_GEOM
    FROM TWEETS_PLACES AS TP
        INNER JOIN CARRETERAS AS R ON TP.ROAD_GID=R.GID 
        INNER JOIN TWEETS AS T ON TP.TWEET_ID=T.TWEET_ID '''
# TWEETS_PLACES(TWEET_ID, ROAD_GID, PLACE_ID)
twt_roads = gpd.GeoDataFrame.from_postgis(q1, conn, geom_col='road_geom')

# %%
# Get tweets places
conn = ps.connect(
    database='traffictwt', user='postgres', password='root')
q1 = '''SELECT TP.TWEET_ID, T.TWEET_TEXT, P.NAME AS PLACE_NAME, ST_CENTROID(P.WAY) as PLACE_GEOM
    FROM TWEETS_PLACES AS TP
        INNER JOIN TWEETS AS T ON TP.TWEET_ID=T.TWEET_ID 
        INNER JOIN PLACES AS P ON TP.PLACE_ID=P.OSM_ID '''
# TWEETS_PLACES(TWEET_ID, ROAD_GID, PLACE_ID)
twt_places = gpd.GeoDataFrame.from_postgis(q1, conn, geom_col='place_geom')
twt_places.place_geom = twt_places.place_geom.to_crs(epsg=4326)

# %%
fig = go.Figure(
    [go.Scattermapbox(
        lat=twt_roads['road_geom'].y, 
        lon=twt_roads['road_geom'].x,
        marker=go.scattermapbox.Marker(
            size=10,
            color='red',
            opacity=0.7
        ),
        text=twt_roads['tweet_text'].str.wrap(30).apply(lambda x: 
            x.replace('\n', '<br>')),
        hoverinfo=['text'],
        hovertemplate='%{text}<extra></extra>'
    # ),
    # go.Scattermapbox(
    #     lat=twt_places['place_geom'].y, 
    #     lon=twt_places['place_geom'].x,
    #     marker=go.scattermapbox.Marker(
    #         size=10,
    #         color='blue',
    #         opacity=0.7
    #     ),
    #     text=twt_places['tweet_text'].str.wrap(30).apply(lambda x: 
    #         x.replace('\n', '<br>')),
    #     hoverinfo=['text'],
    #     hovertemplate='%{text}<extra></extra>'
    )]
)
fig.update_geos(
    resolution=110,
)
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0},
    mapbox_style="open-street-map", mapbox_zoom=11.5,
    mapbox_center={'lat':8.98, 'lon':-79.5359},
    hoverlabel=dict(
        bgcolor="white",
        font_size=12,
    )
)
fig.show()

# %%
## Merge tweets to get roads and places in one dataframe
twt_roads.merge(twt_places, how='outer', on=['tweet_id', 'tweet_text'])
# Out:
#                 tweet_id                                         tweet_text  \
# 0    1401320841711923200  [VÍDEO] Se registra colisión en la Avenida Ric...
# 1    1401277242362281985  Vistas del tráfico en la Avenida Domingo Díaz,...
# 2    1401256978396192770  Trabajos en la Cinta Costera, mantiene el tráf...
# 3    1401255933825671170  [VÍDEO] Se registra colisión en la Carretera P...
# 4    1401232228118634499  [VÍDEO] Trabajos en la Cinta Costera, mantiene...
# ..                   ...                                                ...
# 434  1397259083263193093  Protesta en la vía Transístmica, frente al Com...
# 435  1397258426686791680  Reportan inundaciones en la barriada Plaza Val...
# 436  1397257812842065924  Reportan inundadaciones en la Barriada Plaza V...
# 437  1397256955857625089  [VÍDEO] Protesta en la Vía Transístmica, próxi...
# 438  1397256408329039872  [VÍDEO] Se registra accidente de tránsito en L...
#
#                      road_name                  road_geom  \
# 0    Avenida Ricardo J. Alfaro  POINT (-79.53378 8.99212)
# 1                    Avenida A  POINT (-79.54603 8.95116)
# 2                Cinta Costera  POINT (-79.53999 8.95783)
# 3       Carretera Panamericana  POINT (-80.56366 8.24666)
# 4                Cinta Costera  POINT (-79.53999 8.95783)
# ..                         ...                        ...
# 434                        NaN                       None
# 435                        NaN                       None
# 436                        NaN                       None
# 437                        NaN                       None
# 438                        NaN                       None
#
#                place_name                 place_geom
# 0                     NaN                       None
# 1             San Antonio  POINT (-79.44505 9.05188)
# 2         Cinta Costera 1  POINT (-79.52108 8.97516)
# 3            Panamericana  POINT (-79.52278 8.98787)
# 4         Cinta Costera 1  POINT (-79.52108 8.97516)
# ..                    ...                        ...
# 434         San Miguelito  POINT (-79.50659 9.03002)
# 435     Plaza Villa Zaita  POINT (-79.51669 9.08132)
# 436     Plaza Villa Zaita  POINT (-79.51669 9.08132)
# 437    Carga Transistmica  POINT (-79.37505 9.08259)
# 438  Plaza Interamericana  POINT (-79.70897 8.92677)
#
# [439 rows x 6 columns]

# %% [markdown]
# Tomar la vía
# -> si detecta la vía, tomar lugares adyacentes a la vía, luego hacer un fuzzy match a los lugares cercanos y asignar la intersección
#
# Si no detecta una vía, hacer fuzzy match al texto por un lugares
#
# Si no, asignar nulo

# %% [markdown]
# ### Create X and Y coordinates for places

# %%
places1.loc[:, 'x'] = places1.apply(lambda row: getPointCoords(row, 'geom', 'x'), axis=1)
places1.loc[:, 'y'] = places1.apply(lambda row: getPointCoords(row, 'geom', 'y'), axis=1)

# %%
def getPointCoords(row, geom, coord_type):
    """Calculates coordinates ('x' or 'y') of a Point geometry"""
    if coord_type == 'x':
        return row[geom].x
    elif coord_type == 'y':
        return row[geom].y

# %%
places = places[places.name.str.len()>5]

# %% [markdown]
# ## Extract Places

# %%
extract = Preprocessing.clean_text(tweets, 'text')
# tweets.clean.str.findall('([A-Z]\S+)')
# re.findall('([A-Z]\S+)', tweets)
extract['possible_place'] = extract.clean.str.findall('([A-Z]\S+)')

# %%
extract = extract[extract.clean.str.contains('accident.*|cho[qc].*|colision.*|vuelco|volcó|vuelca|atropell.*|tran[qc].*|embotella.*|trafico|huelga|protest.*|trabajo.*|cierr.*|detenid.*|obstacul.*|incendi.*|inunda.*|lluvia')]
extract = extract[extract.clean.str.len()>30]
extract = extract[extract.possible_place.notnull()]

# %% [markdown]
# ### Fuzzy match tests

# %%
## Fuzzy match tests
test = 'tranque pesado en la Via Brasil hacia el interior'
matches1 = [fuzz.token_sort_ratio(place, test) for place in places.name]
# sum(matches1)
matches2 = [fuzz.token_set_ratio(place, test) for place in places.name]
# max(matches2)

# %%
process.extract(test, places, scorer=fuzz.token_set_ratio)

# %%
extract['contains'] = extract['clean'].apply(lambda x: np.array([]))
# extract['contains'] = extract['contains'].astype(object)
extract['possible'] = extract['clean'].apply(lambda x: np.array([]))
# extract['possible'] = extract['possible'].astype(object)

# %%
extract.drop(columns=['contains', 'possible'], inplace=True)

# %%
extract2 = extract.copy()

# %%
def get_road(text, roads, scorer=fuzz.token_set_ratio):
    '''Applies fuzzy match to extract the possible road of the text.'''
    choice = process.extractOne(text, roads.nombre, scorer=scorer)
    if choice[1]>=80:
        # Returns the gid
        return str(roads.iloc[roads.index==choice[2], 0].iloc[0])
    else: return ''

# %%
def get_place(text, places, scorer=fuzz.token_set_ratio):
    '''Applies fuzzy match to extract the possible road of the text.'''
    choice = process.extractOne(text, places.name, scorer=scorer)
    if choice[1]>=80:
        # Returns the osm_id
        return str(places.iloc[places.index==choice[2], 0].iloc[0])
    else: return ''

# %%
places.head(1)

# %%
extract2 = extract[500:1000]

# %%
## Tackes an extract and searches the possible road
extract2.loc[:, 'road'] = extract2.apply(lambda row: get_road(row.clean, roads), axis=1)
# Out:
# C:\Users\lucia\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\indexing.py:1597: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\lucia\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\indexing.py:1676: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
## Takes part of extract and searches possible place
extract2.loc[:, 'place'] = extract2.apply(lambda row: get_place(row.clean, places), axis=1)

# %%
## Inserting results into database
conn = ps.connect(
    database='traffictwt', user='postgres', password='root')
cursor = conn.cursor()
ins = '''INSERT INTO TWEETS_PLACES(TWEET_ID, ROAD_GID, PLACE_ID)
    VALUES (%s, %s, %s) '''
for index, row in extract2.iterrows():
    cursor.execute(ins, 
        (row['id'], None if row['road']=='' else row['road'], 
            None if row['place']=='' else row['place']))
    conn.commit()
cursor.close()
conn.close()

# %%
extract2
# Out:
#                        id                                               text  \
# 762   1397250548118794244  Camión articulado detenido y en medio de una c...
# 763   1397248875363250185  Se registra accidente de tránsito en el Corred...
# 764   1397243505769164800  [VÍDEO] Se registra accidente de tránsito en e...
# 765   1397243504280145921  [VÍDEO] Mula detenida en la Vía Centenario, pr...
# 766   1397227764277780499  Protesta por calle\n\nResidentes de Gonzalillo...
# ...                   ...                                                ...
# 1571  1391083910914842625  [VÍDEO] Se registra accidente de tránsito en L...
# 1572  1391082349895507969  [VÍDEO] Se registra accidente en la Vía España...
# 1573  1391078584329068552  [VÍDEO] Se registra colisión en la Avenida Ric...
# 1574  1391077923894042624  [VÍDEO] Vistas del tráfico en la Vía Interamer...
# 1575  1391076822293614592  [VÍDEO] Se registra accidente de tránsito en l...
#
#                                                   clean  \
# 762   camion articulado detenido medio columna humo ...
# 763   registra accidente transito Corredor Norte Tin...
# 764   registra accidente transito Corredor Norte Tin...
# 765   mula detenida Via Centenario Rod Carew direcci...
# 766   protesta calle Residentes Gonzalillo salieron ...
# ...                                                 ...
# 1571  registra accidente transito Via Centenario Rod...
# 1572  registra accidente Via España Cresta direccion...
# 1573  registra colision Avenida Ricardo J Alfaro San...
# 1574  vistas trafico Via Interamericana Coronado dir...
# 1575  registra accidente transito via principal Bris...
#
#                                          possible_place      place  road
# 762   [Via, Centenario, Rod, Carew, Panama, Oeste, V...  385466258
# 763   [Corredor, Norte, Tinajitas, Panama, Centro, V...  684868242  2162
# 764        [Corredor, Norte, Tinajitas, Panama, Centro]  684868242  2162
# 765        [Via, Centenario, Rod, Carew, Panama, Oeste]  385466258
# 766                     [Residentes, Gonzalillo, Video]  412554328
# ...                                                 ...        ...   ...
# 1571       [Via, Centenario, Rod, Carew, Panama, Oeste]  385466258
# 1572              [Via, España, Cresta, Panama, Centro]
# 1573  [Avenida, Ricardo, Alfaro, San, Miguel, Arcang...             2192
# 1574    [Via, Interamericana, Coronado, Interior, Pais]  384384811
# 1575                                     [Brisas, Golf]  684868247
#
# [500 rows x 6 columns]

# %% [markdown]
# ## More detailed process with intweet and possible place

# %%
# extract1 = extract.copy()
tweets = Detection.get_classifications(tweets, 'text')

# %%
tweets['contains'] = tweets['clean'].apply(lambda x: np.array([]))
tweets['contains'] = tweets['contains'].astype(object)
tweets['possible'] = tweets['clean'].apply(lambda x: np.array([]))
tweets['possible'] = tweets['possible'].astype(object)

# %%
tweets.iloc[12, 2]
# Out:
# 'lucha joven mujer sufrio graves lesiones accidente transito via Santa Elena Parque Lefevre 22 octubre entrara quirofano allegados familiares '

# %%
intweet = []; possible = []
for index_place, place in places.iterrows():
    if place['name'] in tweets.iloc[12, 2]: 
        print(place['name'], fuzz.token_sort_ratio(place['name'], tweets.iloc[12, 2]))
        intweet.append([fuzz.token_sort_ratio(place['name'], tweets.iloc[12, 2]), place['osm_id']])
max(intweet)
# Out:
# Parque 8
# Parque Lefevre 18
# Parque 8
# Parque 8

# %%
## Searches if a place is exactly in the text or a possible match
# for index, tweet in extract[:100].iterrows():
for index, tweet in tweets.iterrows():
    intweet = []; possible = []

    ## Iteration of the places in the database
    for index_place, place in places.iterrows():
        if len(place['name'])>5:
            if place['name'] in tweet['clean']:
                # Insert the ratio and place ID
                intweet.append([fuzz.token_sort_ratio(place['name'], tweets.iloc[12, 2]), place['osm_id']])
            elif (fuzz.token_set_ratio(place['name'], tweet['clean'])==100 
                and fuzz.token_sort_ratio(place['name'], tweet['clean'])>50) or (fuzz.token_set_ratio(place['name'], tweet['clean'])>90):
                possible.append([fuzz.token_sort_ratio(place['name'], tweets.iloc[12, 2]), place['osm_id']])
    if len(intweet)>0:
        tweets.loc[index, 'contains_place'] = max(intweet)[1]
    if len(possible)>0:
        tweets.loc[index, 'possible_place'] = max(possible)[1] # np.array(possible)

    ## Same process with roads
    intweet = []; possible = []
    ## Iteration of roads
    for index_road, road in roads.iterrows():
        if len(road['nombre'])>5:
            if road['nombre'] in tweet['clean']:
                # Insert the ratio and road ID
                intweet.append([fuzz.token_sort_ratio(road['nombre'], tweets.iloc[12, 2]), road['gid']])
            elif (fuzz.token_set_ratio(road['nombre'], tweet['clean'])==100 
                and fuzz.token_sort_ratio(road['nombre'], tweet['clean'])>50) or (fuzz.token_set_ratio(road['nombre'], tweet['clean'])>90):
                possible.append([fuzz.token_sort_ratio(road['nombre'], tweets.iloc[12, 2]), road['gid']])
    if len(intweet)>0:
        tweets.loc[index, 'contains_road'] = max(intweet)[1]
    if len(possible)>0:
        tweets.loc[index, 'possible_road'] = max(possible)[1] # np.array(possible)

# %%
tweets
# Out:
#                      id                                               text  \
# 0   1452089575137071107  Vistas del tráfico en el Corredor Sur, próximo...
# 1   1452088032543354886  [VÍDEO] Vistas del tráfico en el Corredor Sur,...
# 2   1452057573889302530  Que alguien me diga, cuál es la moda con estac...
# 3   1452036628608868362               Vistas del tráfico en Punta Pacífica
# 4   1452014823739383811  Se registra colisión frente al Mr. Precio de L...
# 5   1452006628736311303  Ah por cierto \n@NaturgyPa\n La Chorrera Rauda...
# 6   1451996134986108931  Más vistas del accidente de en el túnel entre ...
# 7   1451995140197859328  Accidente de tránsito en el viaducto de vía Br...
# 8   1451994558124990465  Vistas del tráfico en sobre el Puente de Las A...
# 9   1451982772294275077                Reportan colisión en la vía Porras.
# 10  1451961083632181259  Vistas del tráfico en la vía Mariano Rivera ce...
# 11  1451946393317281794  [VIDEO] A través de Vídeo Vigilancia del Centr...
# 12  1451942494296543232  Sigue la lucha. La joven mujer que sufrió grav...
# 13  1451941319971061762  Tráfico fluido en la Vía Interamericana, en Sa...
# 14  1451940767476367363  Colisión en la Vía Cincuentenario en  Balboa. ...
# 15  1451937066858713089  [VIDEO] Tras un incidente de tránsito, se rest...
# 16  1451927350128545797  [VIDEO] Se realizan labores de remoción de pos...
# 17  1451925377497042947           Colisión en la rotonda hacia Vía Brasil.
# 18  1451917488460115976  Flujo vehicular afectado en la vía Interameric...
# 19  1451915179944513545  Accidente de tránsito en la Avenida Ernesto T....
# 20  1451911075700609036  PROMO de apertura desde 79$ P/P en base a ocup...
# 21  1451901908701036551  Se registra accidente de tránsito en la vía Pa...
# 22  1451901022448848903  Se registra accidente de tránsito en La Vía In...
# 23  1451900208888045576  Se mantiene el tráfico afectado en la Vía Inte...
# 24  1451897843866873871  [VIDEO] Através de las cámaras  de  del Centro...
# 25  1451896145861648384  Tráfico lento en la vía Interamericana en Capi...
# 26  1451894133702995968  [VIDEO] Más vistas del accidente de tránsito e...
# 27  1451891952421638144  Dos autos involucrados en accidente de tránsit...
# 28  1451891404574187525  Un lesionado deja accidente de tránsito en La ...
# 29  1451890808240619527  [VÍDEO] Se mantiene el tráfico afectado en amb...
# 30  1451890538358231040  Usuarios reportan que la Línea 1 del Metro de ...
# 31  1451889608111841283  [VÍDEO] Se registra accidente de tránsito múlt...
# 32  1451887997213937670  Usuarios reportan que la Línea 1 del Metro de ...
# 33  1451887653603971076  Se registra accidente de tránsito en La Vía In...
# 34  1451887474737811459  Se registra accidente de tránsito múltiple en ...
# 35  1451887356101992451  Feliz sábado a todos nuestros seguidores excel...
# 36  1451763061459664896  [VÍDEO] Más vistas del accidente de tránsito e...
# 37  1451743715551322116  Se registra accidente de tránsito en La Vía In...
# 38  1451731119074852867  [VÍDEO] Auto con desperfectos mecánicos en la ...
# 39  1451727304107995140  ¿Quieres que tu auto se vea como nuevo otra ve...
# 40  1451727296969195522  Las ofertas especiales de #MaxWeek continúan y...
# 41  1451716549497196546  Tráfico denso en Avenida de Los Mártires con d...
# 42  1451715821370228738  Tráfico pesado en la vía Interamericana en Gua...
# 43  1451679922150326275  Hace dos horas el trafico en el camino hacia S...
# 44  1451677125665337350       Cierre de vía por protesta cerca de La Joya.
# 45  1451676171788341248    [VIDEO] Cierre  en Utivé antes del Río Cabobre.
# 46  1451674869247189000  #LOÚLTIMO \n\nReportan incendio en un edificio...
# 47  1451673768577966082  A 10km/h se desplazan los autos en la Vía Inte...
# 48  1451673451928883200  A 10km/h se desplazan los autos sobre el Puent...
# 49  1451672618378174475  Reportan incendio en un edificio ubicado en la...
#
#                                                 clean  isIncident      prob  \
# 0   vistas trafico Corredor Sur Paitilla direccion...       False  0.498333
# 1   vistas trafico Corredor Sur Paitilla direccion...       False  0.461667
# 2   alguien diga cual moda estacionar retroceso mi...       False  0.013333
# 3                       vistas trafico Punta Pacifica       False  0.087465
# 4   registra colision frente Mr Precio Chorrera pr...        True  0.784167
# 5            ah Chorrera Raudal 1 semana bajones luz        False  0.013333
# 6         vistas accidente tunel via Brasil Calle 50         True  0.622158
# 7    accidente transito viaducto via Brasil Calle 50         True  0.600768
# 8                     vistas trafico Puente Americas        False  0.122703
# 9                       reportan colision via Porras        False  0.286784
# 10  vistas trafico via Mariano Rivera hospital Nic...       False  0.180556
# 11  Video Vigilancia Centro Operacion Nacional cap...       False  0.395833
# 12  lucha joven mujer sufrio graves lesiones accid...       False  0.281111
# 13  trafico fluido Via Interamericana Sajaciles Ch...       False  0.155856
# 14     colision Via Cincuentenario Balboa Precaucion        False  0.059588
# 15  incidente transito restablece trafico via Inte...        True  0.506667
# 16  realizan labores remocion postes via Interamer...        True  0.580069
# 17                       colision rotonda Via Brasil        False  0.084605
# 18  flujo vehicular afectado via Interamericana Ca...        True  0.695199
# 19      accidente transito Avenida Ernesto T Lefevre         True  0.786473
# 20  pROMO apertura 79 P P base ocupacion doble Dom...       False  0.096667
# 21  registra accidente transito via Panamericana a...        True  0.894306
# 22  registra accidente transito Via Interamericana...        True  0.869931
# 23  mantiene trafico afectado Via Interamericana L...        True  0.799353
# 24  atraves camaras Centro Operacion Nacional obse...       False  0.471111
# 25  trafico lento via Interamericana Capira direcc...       False  0.462500
# 26  vistas accidente transito via Interamericana L...        True  0.651153
# 27  autos involucrados accidente transito Autopist...        True  0.767833
# 28  lesionado deja accidente transito Via Interame...        True  0.754333
# 29  mantiene trafico afectado ambas direcciones Vi...        True  0.793292
# 30  usuarios reportan Linea 1 Metro Panama mantien...        True  0.768821
# 31  registra accidente transito multiple Avenida D...        True  0.955417
# 32  usuarios reportan Linea 1 Metro Panama mantien...        True  0.779655
# 33  registra accidente transito Via Interamericana...        True  0.934750
# 34  registra accidente transito multiple Avenida D...        True  0.967917
# 35  feliz sabado seguidores excelente dia exitos l...       False  0.001667
# 36  vistas accidente transito Via Interamericana A...        True  0.702500
# 37  registra accidente transito Via Interamericana...        True  0.899375
# 38  auto desperfectos mecanicos Via Tocumen Aeropu...        True  0.738333
# 39  quieres tu auto vea Te gustaria recuperarlo te...       False  0.049167
# 40  ofertas especiales continuan te encantar Agreg...       False  0.001667
# 41  trafico denso Avenida Martires direccion Puent...       False  0.280728
# 42  trafico pesado via Interamericana Guabala Tole...       False  0.204084
# 43  horas trafico camino San Martin San Miguel det...        True  0.850000
# 44                          cierre via protesta Joya         True  0.863681
# 45                          cierre Utive Rio Cabobre         True  0.696667
# 46  reportan incendio edificio Avenida Balboa hech...        True  0.868333
# 47  10kmh desplazan autos Via Interamericana Loma ...        True  0.745000
# 48  10kmh desplazan autos Puente Americas direccio...        True  0.731667
# 49  reportan incendio edificio ubicado Avenida Bal...        True  0.836667
#
#     isAccident  isObstacle  isDanger  contains_place  contains_road  \
# 0        False       False     False     684868242.0         2270.0
# 1        False       False     False     684868242.0         2270.0
# 2        False       False     False             NaN            NaN
# 3        False       False     False             NaN            NaN
# 4         True       False     False             NaN            NaN
# 5        False       False     False             NaN            NaN
# 6         True       False     False             NaN            NaN
# 7         True       False     False             NaN            NaN
# 8        False       False     False             NaN            NaN
# 9        False       False     False             NaN            NaN
# 10       False       False     False             NaN            NaN
# 11       False       False     False             NaN            NaN
# 12       False       False     False     -11380922.0            NaN
# 13       False       False     False             NaN            NaN
# 14       False       False     False     666341239.0            NaN
# 15       False       False     False             NaN            NaN
# 16        True       False     False             NaN            NaN
# 17       False       False     False             NaN            NaN
# 18        True       False     False             NaN            NaN
# 19        True       False     False             NaN            NaN
# 20       False       False     False     387015498.0            NaN
# 21        True       False     False     382551098.0            NaN
# 22        True       False     False             NaN            NaN
# 23        True       False     False             NaN            NaN
# 24       False       False     False             NaN            NaN
# 25       False       False     False             NaN            NaN
# 26        True       False     False             NaN            NaN
# 27        True       False     False     -11381034.0            NaN
# 28        True       False     False             NaN            NaN
# 29        True       False     False             NaN            NaN
# 30       False        True      True             NaN            NaN
# 31        True       False     False     727344164.0            NaN
# 32       False        True      True             NaN            NaN
# 33        True       False     False             NaN            NaN
# 34        True       False     False     727344164.0            NaN
# 35       False       False     False             NaN            NaN
# 36        True       False     False             NaN            NaN
# 37        True       False     False             NaN            NaN
# 38       False        True     False     387017524.0            NaN
# 39       False       False     False             NaN            NaN
# 40       False       False     False             NaN            NaN
# 41       False       False     False             NaN            NaN
# 42       False       False     False             NaN            NaN
# 43       False        True     False             NaN            NaN
# 44       False        True     False             NaN            NaN
# 45       False        True     False             NaN            NaN
# 46       False       False      True     385183957.0         2121.0
# 47       False        True     False             NaN            NaN
# 48       False        True     False             NaN            NaN
# 49       False       False      True     385183957.0         2121.0
#
#     possible_place  possible_road
# 0              NaN            NaN
# 1              NaN            NaN
# 2              NaN            NaN
# 3              NaN            NaN
# 4      384089871.0            NaN
# 5              NaN            NaN
# 6              NaN            NaN
# 7              NaN            NaN
# 8              NaN            NaN
# 9              NaN            NaN
# 10             NaN            NaN
# 11             NaN            NaN
# 12     412553927.0            NaN
# 13             NaN            NaN
# 14             NaN            NaN
# 15             NaN            NaN
# 16             NaN            NaN
# 17             NaN            NaN
# 18             NaN            NaN
# 19             NaN         2215.0
# 20             NaN            NaN
# 21             NaN            NaN
# 22             NaN            NaN
# 23             NaN            NaN
# 24             NaN            NaN
# 25             NaN            NaN
# 26             NaN            NaN
# 27             NaN            NaN
# 28             NaN            NaN
# 29             NaN            NaN
# 30             NaN            NaN
# 31             NaN            NaN
# 32             NaN            NaN
# 33             NaN            NaN
# 34             NaN            NaN
# 35     385459943.0            NaN
# 36             NaN            NaN
# 37             NaN            NaN
# 38     385900511.0            NaN
# 39             NaN            NaN
# 40     591899402.0            NaN
# 41             NaN            NaN
# 42             NaN            NaN
# 43             NaN            NaN
# 44             NaN            NaN
# 45             NaN            NaN
# 46     383638703.0            NaN
# 47             NaN            NaN
# 48             NaN            NaN
# 49     383638703.0            NaN

# %%
## Inserting results into database
conn = ps.connect(
    database='traffictwt', user='postgres', password='root')
cursor = conn.cursor()
ins = '''INSERT INTO TWEETS_PLACES(TWEET_ID, ROAD_GID, PLACE_ID)
    VALUES (%s, %s, %s) '''
for index, row in extract2.iterrows():
    cursor.execute(ins, 
        (row['id'], None if row['road']=='' else row['road'], 
            None if row['place']=='' else row['place']))
    conn.commit()
cursor.close()
conn.close()

# %%
## Merge tweets to get roads and places in one dataframe
twt_roads.merge(twt_places, how='outer', on=['tweet_id', 'tweet_text'])
